# %%
import pandas as pd
import plotly as pl

# %%
df_AAPL = pd.read_csv('AAPL_stock_price.csv')
df_MSFT = pd.read_csv('MSFT_stock_price.csv')
df_AAPL.dropna(axis=1)
df_MSFT.dropna(axis=1)
# Out:
#             Date  Open Price  High Price  Low Price  Close Price      Volume
# 0     1999-11-01      93.250       94.19      92.12        92.37  26630600.0
# 1     1999-11-02      92.750       94.50      91.94        92.56  23174500.0
# 2     1999-11-03      92.940       93.50      91.50        92.00  22258500.0
# 3     1999-11-04      92.310       92.75      90.31        91.75  27119700.0
# 4     1999-11-05      91.810       92.87      90.50        91.56  35083700.0
# ...          ...         ...         ...        ...          ...         ...
# 6276  2024-10-11     416.135      417.13     413.25       416.32  14144944.0
# 6277  2024-10-14     417.770      424.04     417.52       419.14  16653086.0
# 6278  2024-10-15     422.180      422.48     415.26       418.74  18900201.0
# 6279  2024-10-16     415.170      416.36     410.48       416.12  15508932.0
# 6280  2024-10-17     422.360      422.50     415.59       416.72  14820004.0
#
# [6281 rows x 6 columns]

# %%
import plotly.graph_objs as go

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=df_AAPL['Date'], y=df_AAPL['Close Price'],
                         mode='lines', name='AAPL',
                         line=dict(color='blue')))
fig.add_trace(go.Scatter(x=df_MSFT['Date'], y=df_MSFT['Close Price'],
                         mode='lines', name='MSFT',
                         line=dict(color='red')))
fig.update_layout(title='Preço de Fechamento da AAPL e MSFT',
                  xaxis_title='Data',
                  yaxis_title='Preço de Fechamento',
                  shapes=[
                      dict(
                          x0='2019-01-22', x1='2019-01-22',
                          y0=0, y1=1,
                          xref='x', yref='paper',
                          line_width=2, line_color='blue'
                      ),dict(
                          x0='2012-09-25', x1='2012-09-25',
                          y0=0, y1=1,
                          xref='x', yref='paper',
                          line_width=2, line_color='blue'
                      ),dict(
                          x0='2020-11-25', x1='2020-11-25',
                          y0=0, y1=1,
                          xref='x', yref='paper',
                          line_width=2, line_color='red'
                      ),dict(
                        type='line',
                        x0=df_AAPL['Date'].min(),  
                        y0=210,  
                        x1=df_AAPL['Date'].max(), 
                        y1=210,  
                        line=dict(
                            color='green',  
                            width=2,  
                            dash='dash'  
                        )
                    )
                  ],
                  annotations=[dict(
                      x='2019-01-22', y=0.95, yref='paper',
                      showarrow=False,
                      xanchor='right',
                      text='Increase Period'
                  ),dict(
                      x='2012-09-25', y=0.98, yref='paper',
                      showarrow=False,
                      xanchor='right',
                      text='Decrease Period'
                  ),dict(
                      x='2020-11-25', y=0.98, yref='paper',
                      showarrow=False,
                      xanchor='left',
                      text='Increase Period'
                  )]
                 )
fig.show()
# Out:
# <div>                            <div id="8400acf3-e746-405b-9e4b-a8f075fce62a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8400acf3-e746-405b-9e4b-a8f075fce62a")) {                    Plotly.newPlot(                        "8400acf3-e746-405b-9e4b-a8f075fce62a",                        [{"line":{"color":"blue"},"mode":"lines","name":"AAPL","x":["1999-11-01","1999-11-02","1999-11-03","1999-11-04","1999-11-05","1999-11-08","1999-11-09","1999-11-10","1999-11-11","1999-11-12","1999-11-15","1999-11-16","1999-11-17","1999-11-18","1999-11-19","1999-11-22","1999-11-23","1999-11-24","1999-11-26","1999-11-29","1999-11-30","1999-12-01","1999-12-02","1999-12-03","1999-12-06","1999-12-07","1999-12-08","1999-12-09","1999-12-10","1999-12-13","1999-12-14","1999
# ...
